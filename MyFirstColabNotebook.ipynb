# %% [markdown]
# <a href="https://colab.research.google.com/github/Naseemah-dev/googlecolab/blob/main/MyFirstColabNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Fri Jan 30 11:14:22 2026

# %%
time.sleep(5)
print(time.ctime())
# Out:
# Fri Jan 30 11:14:27 2026

# %% [markdown]
# This is **bold**.
# This is *italic*.
# This is ~strikethrough~.

# %% [markdown]
# $\sqrt{3x-1}+(1+x)^2$
